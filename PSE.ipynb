# %% [markdown]
# <a href="https://colab.research.google.com/github/aish0606/PSENet/blob/main/PSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd "/gdrive/My Drive/Codes/PSENet"
# Out:
# /gdrive/My Drive/Codes/PSENet

# %%
# !git clone https://github.com/liuheng92/tensorflow_PSENet.git
# Out:
# Cloning into 'tensorflow_PSENet'...
# remote: Enumerating objects: 193, done.
# remote: Total 193 (delta 0), reused 0 (delta 0), pack-reused 193
# Receiving objects: 100% (193/193), 1.23 MiB | 10.03 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
cd "/gdrive/My Drive/Codes/PSENet/sroie"
# Out:
# /gdrive/.shortcut-targets-by-id/1GKRYvNe4JVjFJO4WhDlyglV8G06R5Vyz/sroie

# %%
# !ls
# Out:
#  gt_X00016469672.txt	    gt_X51006620175.txt        X51006328345.jpg
#  gt_X51005200938.txt	    gt_X51006620181.txt        X51006328937.jpg
#  gt_X51005301666.txt	    gt_X51006620189.txt        X51006329399.jpg
#  gt_X51005303661.txt	    gt_X51006679222.txt        X51006332649.jpg
# 'gt_X51005361907 (1).txt'   gt_X51006857137.txt        X51006334819.jpg
#  gt_X51005361912.txt	    gt_X51006912998.txt        X51006387737.jpg
#  gt_X51005365179.txt	    gt_X51006913024.txt        X51006387740.jpg
#  gt_X51005442397.txt	    gt_X51006913031.txt        X51006388066.jpg
#  gt_X51005453801.txt	    gt_X51006913067.txt        X51006388082.jpg
#  gt_X51005587267.txt	    gt_X51006913074.txt        X51006401845.jpg
# 'gt_X51005605285 (3).txt'   gt_X51007103668.txt        X51006401940.jpg
#  gt_X51005605287.txt	    gt_X51007231276.txt        X51006414425.jpg
#  gt_X51005663274.txt	   'gt_X51007231336 (1).txt'   X51006414600.jpg
#  gt_X51005663278.txt	    gt_X51007231346.txt        X51006414721.jpg
# ...

# %%
# %cd "/gdrive/My Drive/sroie/test"
# Out:
# /gdrive/.shortcut-targets-by-id/1GKRYvNe4JVjFJO4WhDlyglV8G06R5Vyz/sroie/test

# %%
# !cp -r /gdrive/My\ Drive/sroie/ /gdrive/My\ Drive/Codes/PSENet/

# %%
# %cd "/gdrive/My Drive/Codes/PSENet/sroie/test"
# Out:
# /gdrive/My Drive/Codes/PSENet/sroie/test

# %%
# !cp "/gdrive/My Drive/Codes/PSENet/sroie/rename.py" .

# %%
pwd
# Out:
# '/gdrive/My Drive/Codes/PSENet/sroie/test'

# %%
# !python rename.py
# Out:
# gt_X00016469672.txt --> X00016469672.txt
# gt_X51005200938.txt --> X51005200938.txt
# gt_X51005303661.txt --> X51005303661.txt
# gt_X51005361907 (1).txt --> X51005361907 (1).txt
# gt_X51005365179.txt --> X51005365179.txt
# gt_X51005442397.txt --> X51005442397.txt
# gt_X51005453801.txt --> X51005453801.txt
# gt_X51005587267.txt --> X51005587267.txt
# gt_X51005605285 (3).txt --> X51005605285 (3).txt
# gt_X51005663278.txt --> X51005663278.txt
# gt_X51005663324.txt --> X51005663324.txt
# gt_X51005677339.txt --> X51005677339.txt
# gt_X51005685355 (1).txt --> X51005685355 (1).txt
# gt_X51005705804.txt --> X51005705804.txt
# gt_X51005712038.txt --> X51005712038.txt
# gt_X51005719856.txt --> X51005719856.txt
# gt_X51005719917.txt --> X51005719917.txt
# gt_X51005724554.txt --> X51005724554.txt
# gt_X51005741944.txt --> X51005741944.txt
# gt_X51006008197.txt --> X51006008197.txt
# gt_X51006311767.txt --> X51006311767.txt
# gt_X51006311778.txt --> X51006311778.txt
# ...

# %%
cd "/gdrive/My Drive/Codes/PSENet/tensorflow_PSENet"
# Out:
# /gdrive/My Drive/Codes/PSENet/tensorflow_PSENet

# %%
# !pip install pyclipper
# Out:
# ...
#      |████████████████████████████████| 133kB 6.6MB/s
# ...

# %%
# %tensorflow_version 1.15
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# !python train.py --gpu_list=0 --input_size=512 --batch_size_per_gpu=4 --checkpoint_path=./checkpoint1/ \
--training_data_path=/gdrive/My\ Drive/Codes/sroie/train
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# DEBUG:matplotlib:CONFIGDIR=/root/.config/matplotlib
# DEBUG:matplotlib:(private) matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# ...

# %%
# !python3 eval.py --test_data_path=/gdrive/My\ Drive/Codes/sroie/test --gpu_list=0 --checkpoint_path=./checkpoint1/ \
--output_dir=/gdrive/My\ Drive/Codes/PSENet/tensorflow_PSENet/psenet_result
# Out:
# DEBUG:matplotlib:CONFIGDIR=/root/.config/matplotlib
# DEBUG:matplotlib:(private) matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# DEBUG:matplotlib:matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# DEBUG:matplotlib:loaded rc file /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/matplotlibrc
# DEBUG:matplotlib:matplotlib version 3.2.2
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# ...

# %%
# !grep -ir "_Py_ZeroStruct"
# Out:
# Binary file pse/pse.so matches

# %%
# %cd /gdrive/My\ Drive/Codes/PSENet/tensorflow_PSENet/
# Out:
# /gdrive/My Drive/Codes/PSENet/tensorflow_PSENet

# %%
# !ls -la
# Out:
# total 1903
# drwx------ 3 root root    4096 Jul 16 05:32 include
# -rw------- 1 root root     890 Jul 16 07:56 __init__.py
# -rw------- 1 root root     319 Jul 16 05:32 Makefile
# -rw------- 1 root root    3266 Jul 16 05:32 pse.cpp
# -rwx------ 1 root root 1934488 Jul 16 07:54 pse.so
# drwx------ 2 root root    4096 Jul 16 07:53 __pycache__

# %%
# !python2 --version
# Out:
# Python 2.7.17

# %%
# !apt install python3-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-dev is already the newest version (3.6.7-1~18.04).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
# %cd "/gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/pse"
# Out:
# /gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/pse

# %%
# !ls -la
# Out:
# total 13
# drwx------ 3 root root 4096 Jul 16 05:32 include
# -rw------- 1 root root  890 Jul 16 07:56 __init__.py
# -rw------- 1 root root  325 Jul 16 09:03 Makefile
# -rw------- 1 root root 3266 Jul 16 05:32 pse.cpp
# drwx------ 2 root root 4096 Jul 16 08:04 __pycache__

# %%
# !rm pse.so

# %%
# !python train.py --gpu_list=0 --input_size=512 --batch_size_per_gpu=2 --checkpoint_path=./checkpoint2/ \
--training_data_path=/gdrive/My\ Drive/Codes/PSENet/sroie/train/
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# DEBUG:matplotlib:CONFIGDIR=/root/.config/matplotlib
# DEBUG:matplotlib:(private) matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# ...

# %%
# !python train.py --gpu_list=0 --input_size=512 --restore=True --batch_size_per_gpu=2 --checkpoint_path=./checkpoint2/ \
--training_data_path=/gdrive/My\ Drive/Codes/PSENet/sroie/train/
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# DEBUG:matplotlib:CONFIGDIR=/root/.config/matplotlib
# DEBUG:matplotlib:(private) matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# ...

# %%
# !python train.py --gpu_list=0 --input_size=512 --restore=True --batch_size_per_gpu=2 --checkpoint_path=./checkpoint2/ \
--training_data_path=/gdrive/My\ Drive/Codes/PSENet/sroie/train/
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# DEBUG:matplotlib:CONFIGDIR=/root/.config/matplotlib
# DEBUG:matplotlib:(private) matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# ...

# %%
# !python train.py --gpu_list=0 --input_size=512 --batch_size_per_gpu=4 --checkpoint_path=./checkpoint3/ \
--training_data_path=/gdrive/My\ Drive/Codes/PSENet/sroie/train/
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# DEBUG:matplotlib:CONFIGDIR=/root/.config/matplotlib
# DEBUG:matplotlib:(private) matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# ...

# %%
# %cd "/gdrive/My Drive/Codes/PSENet/sroie/test"
# Out:
# /gdrive/My Drive/Codes/PSENet/sroie/test

# %%
ls *.jpg | wc -l
# Out:
# 98

# %%
cp  /gdrive/My\ Drive/Codes/PSENet/sroie/input/

# %%
# %cd "/gdrive/My Drive/Codes/PSENet/tensorflow_PSENet"
# Out:
# /gdrive/My Drive/Codes/PSENet/tensorflow_PSENet

# %%
# !python3 eval.py --test_data_path=../sroie/input/ --gpu_list=0 --checkpoint_path=./checkpoint3/ \
--output_dir=../sroie/result
# Out:
# DEBUG:matplotlib:CONFIGDIR=/root/.config/matplotlib
# DEBUG:matplotlib:(private) matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# DEBUG:matplotlib:matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# DEBUG:matplotlib:loaded rc file /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/matplotlibrc
# DEBUG:matplotlib:matplotlib version 3.2.2
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# ...

# %%
# %cd "/gdrive/My Drive/Codes/PSENet/sroie/test"
# Out:
# /gdrive/My Drive/Codes/sroie/test

# %%
# %cd "/gdrive/My Drive/Codes/sroie/test"
# Out:
# /gdrive/My Drive/Codes/sroie/test

# %%
# %cp X51006311778.jpg X51006619757.jpg X51006311767.jpg X51006619567.jpg X51008142031.jpg X51006008197.jpg X51006619338.jpg X51008123586.jpg /gdrive/My\ Drive/Codes/sroie/input

# %%
# %cd "/gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/checkpoint3"
# Out:
# /gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/checkpoint3

# %%
# %cd "/gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/"
# Out:
# /gdrive/My Drive/Codes/PSENet/tensorflow_PSENet

# %%
!7z a checkpoint3.7z ./checkpoint3/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive:
# 2 folders, 11 files, 1397426651 bytes (1333 MiB)
#
# Creating archive: checkpoint3.7z
#
# Items to compress: 13
#
# 100% 11 + checkpoint3/model.ckpt-506.meta
# Files read from disk: 11
# Archive size: 1257272676 bytes (1200 MiB)
# Everything is Ok

# %%
# !du -sh *
# Out:
# 453M	checkpoint1
# 1.4G	checkpoint2
# 1.4G	checkpoint3
# 1.2G	checkpoint3.7z
# 8.5K	eval.py
# 1.2M	figure
# 1.5K	LICENSE
# 73K	nets
# 2.5M	pse
# 3.0K	readme.md
# 8.0K	train.py
# 54K	utils

# %%
# %cd "/gdrive/My Drive/Codes/PSENet/tensorflow_PSENet"
# Out:
# /gdrive/My Drive/Codes/PSENet/tensorflow_PSENet

# %%
pwd
# Out:
# '/gdrive/My Drive/Codes/PSENet/sroie/output'

# %%
# !rm *

# %%
# %cd "/gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/checkpoint3"
# Out:
# /gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/checkpoint3

# %%
# %cd /gdrive/My\ Drive/Codes/PSENet/tensorflow_PSENet
# Out:
# /gdrive/My Drive/Codes/PSENet/tensorflow_PSENet

# %%
# !python3 eval.py --test_data_path=/gdrive/My\ Drive/Codes/sroie/input --gpu_list=0 \
--checkpoint_path=/gdrive/My\ Drive/Codes/PSENet/tensorflow_PSENet/checkpoint3 \
--output_dir=/gdrive/My\ Drive/Codes/sroie/output
# Out:
# DEBUG:matplotlib:CONFIGDIR=/root/.config/matplotlib
# DEBUG:matplotlib:(private) matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# DEBUG:matplotlib:matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# DEBUG:matplotlib:loaded rc file /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/matplotlibrc
# DEBUG:matplotlib:matplotlib version 3.2.2
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# ...

# %%
# %rm -rf /gdrive/My\ Drive/Codes/sroie/output/*

# %%
cd /gdrive/My\ Drive/Codes/PSENet/tensorflow_PSENet/checkpoint3
# Out:
# /gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/checkpoint3

# %%
ls -la
# Out:
# total 466406
# -rw------- 1 root root       175 Jul 16 12:00 checkpoint
# -rw------- 1 root root  17676379 Jul 16 12:10 events.out.tfevents.1594899545.5d3e7d9885ac
# drwx------ 2 root root      4096 Jul 16 12:52 .ipynb_checkpoints/
# -rw------- 1 root root 454261356 Jul 16 11:50 model.ckpt-506.data-00000-of-00001
# -rw------- 1 root root     35886 Jul 16 11:50 model.ckpt-506.index
# -rw------- 1 root root   5619457 Jul 16 11:50 model.ckpt-506.meta

# %%
mv model.ckpt-1011.data-00000-of-00001 model.ckpt-1011.index model.ckpt-1011.meta ../extra_checkpoint/

# %%
cd /gdrive/My\ Drive/Codes/PSENet/tensorflow_PSENet/extra_checkpoint
# Out:
# /gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/extra_checkpoint

# %%
# !ls -la
# Out:
# total 1347416
# -rw------- 1 root root 454261356 Jul 16 12:00 model.ckpt-1011.data-00000-of-00001
# -rw------- 1 root root     35886 Jul 16 12:00 model.ckpt-1011.index
# -rw------- 1 root root   5619457 Jul 16 12:00 model.ckpt-1011.meta
# -rw------- 1 root root 454261356 Jul 16 11:40 model.ckpt-1.data-00000-of-00001
# -rw------- 1 root root     35886 Jul 16 11:40 model.ckpt-1.index
# -rw------- 1 root root   5619457 Jul 16 11:40 model.ckpt-1.meta
# -rw------- 1 root root 454261356 Jul 16 11:50 model.ckpt-506.data-00000-of-00001
# -rw------- 1 root root     35886 Jul 16 11:50 model.ckpt-506.index
# -rw------- 1 root root   5619457 Jul 16 11:50 model.ckpt-506.meta

# %%
mv model.ckpt-506.data-00000-of-00001 model.ckpt-506.index model.ckpt-506.meta ../checkpoint3/

# %%
# !zip -r PSENet.zip /gdrive/My\ Drive/Codes/PSENet/tensorflow_PSENet/
# Out:
# Scanning files
#   adding: gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/ (stored 0%)
#   adding: gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/.git/ (stored 0%)
#   adding: gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/.git/description (deflated 14%)
#   adding: gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/.git/hooks/ (stored 0%)
#   adding: gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/.git/hooks/update.sample (deflated 68%)
#   adding: gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/.git/hooks/pre-receive.sample (deflated 40%)
# ...

# %%
# !find -name "PSENet.zip"
# Out:
# ./PSENet.zip

# %%
# !ls -la
# Out:
# total 1242574
# drwx------ 3 root root       4096 Jul 16 11:38 checkpoint3
# -rw------- 1 root root       8437 Jul 16 09:02 eval.py
# drwx------ 2 root root       4096 Jul 16 05:32 figure
# drwx------ 8 root root       4096 Jul 16 05:32 .git
# -rw------- 1 root root         17 Jul 16 05:32 .gitignore
# drwx------ 2 root root       4096 Jul 16 06:21 .ipynb_checkpoints
# -rw------- 1 root root       1068 Jul 16 05:32 LICENSE
# drwx------ 4 root root       4096 Jul 16 05:32 nets
# drwx------ 4 root root       4096 Jul 16 05:32 pse
# -rw------- 1 root root 1272344114 Sep  5 17:42 PSENet.zip
# -rw------- 1 root root       2854 Jul 16 05:32 readme.md
# -rw------- 1 root root       7888 Jul 16 13:21 train.py
# drwx------ 4 root root       4096 Jul 16 05:32 utils

# %%
!7z a psenet_result.7z /gdrive/My\ Drive/Codes/PSENet/tensorflow_PSENet/psenet_result
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive:
# 1 folder, 196 files, 54594261 bytes (53 MiB)
#
# Creating archive: psenet_result.7z
#
# Items to compress: 197
#
# 100% 196 + psenet_result/X51008142031.txt
# Files read from disk: 196
# Archive size: 33518943 bytes (32 MiB)
# Everything is Ok

# %%
! du -sh /gdrive/My\ Drive/Codes/PSENet/tensorflow_PSENet/psenet_result.7z
# Out:
# 32M	/gdrive/My Drive/Codes/PSENet/tensorflow_PSENet/psenet_result.7z
